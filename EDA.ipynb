# %% [markdown]
# <a href="https://colab.research.google.com/github/mdeepika12/AIML/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df= pd.read_csv('Ecommerce_Customers_EDA.csv')

# %%
# 1. Understand the data
df.head()
# Out:
#   CustomerID  Gender  Age  Annual Income ($)  Time on App (minutes)  \
# 0   CUST0001    Male   49             106213                  12.05
# 1   CUST0002  Female   56              35895                   7.95
# 2   CUST0003    Male   66              49738                  22.42
# 3   CUST0004    Male   69              60746                  20.72
# 4   CUST0005    Male   49              79377                  26.94
#
#    Time on Website (minutes)  Length of Membership (years)  \
# 0                      20.33                           6.8
# 1                      28.37                           7.2
# 2                      49.20                           5.9
# 3                      29.70                           3.3
# 4                      23.15                           4.1
#
#    Yearly Amount Spent ($)
# 0                  1096.84
# 1                   834.24
# 2                  1270.91
# 3                   606.60
# 4                   575.14

# %%
df.tail()
# Out:
#     CustomerID  Gender  Age  Annual Income ($)  Time on App (minutes)  \
# 195   CUST0196  Female   47              45305                  26.56
# 196   CUST0197  Female   55             105353                  28.74
# 197   CUST0198  Female   55             106797                   8.68
# 198   CUST0199    Male   62              95953                  28.16
# 199   CUST0200    Male   68              87458                  17.30
#
#      Time on Website (minutes)  Length of Membership (years)  \
# 195                      41.89                           1.3
# 196                      16.00                           3.4
# 197                      19.17                           6.4
# 198                      38.89                           1.5
# 199                      38.80                           5.5
#
#      Yearly Amount Spent ($)
# 195                  1134.01
# 196                  1039.99
# 197                  1279.85
# 198                   606.98
# ...

# %%
df.describe()
# Out:
#               Age  Annual Income ($)  Time on App (minutes)  \
# count  200.000000         200.000000             200.000000
# mean    44.405000       76144.275000              18.659850
# std     15.353816       26367.073409               7.571077
# min     18.000000       30301.000000               5.270000
# 25%     32.750000       52956.000000              12.920000
# 50%     46.000000       79533.000000              19.180000
# 75%     56.000000       98549.250000              25.325000
# max     69.000000      119912.000000              29.990000
#
#        Time on Website (minutes)  Length of Membership (years)  \
# count                 200.000000                    200.000000
# mean                   28.311850                      5.229500
# std                    11.167733                      2.573069
# min                    10.800000                      1.000000
# 25%                    17.975000                      2.900000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CustomerID                    200 non-null    object
#  1   Gender                        200 non-null    object
#  2   Age                           200 non-null    int64
#  3   Annual Income ($)             200 non-null    int64
#  4   Time on App (minutes)         200 non-null    float64
#  5   Time on Website (minutes)     200 non-null    float64
#  6   Length of Membership (years)  200 non-null    float64
#  7   Yearly Amount Spent ($)       200 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 12.6+ KB

# %%
df.shape
# Out:
# (200, 8)

# %%
df.nunique()
# Out:
# CustomerID                      200
# Gender                            2
# Age                              50
# Annual Income ($)               200
# Time on App (minutes)           190
# Time on Website (minutes)       194
# Length of Membership (years)     83
# Yearly Amount Spent ($)         200
# dtype: int64

# %%
# 2. Cleaning the data
df.drop('CustomerID', axis=1,inplace=True)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income ($)  Time on App (minutes)  \
# 0    Male   49             106213                  12.05
# 1  Female   56              35895                   7.95
# 2    Male   66              49738                  22.42
# 3    Male   69              60746                  20.72
# 4    Male   49              79377                  26.94
#
#    Time on Website (minutes)  Length of Membership (years)  \
# 0                      20.33                           6.8
# 1                      28.37                           7.2
# 2                      49.20                           5.9
# 3                      29.70                           3.3
# 4                      23.15                           4.1
#
#    Yearly Amount Spent ($)
# 0                  1096.84
# 1                   834.24
# 2                  1270.91
# 3                   606.60
# 4                   575.14

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Age                             0
# Annual Income ($)               0
# Time on App (minutes)           0
# Time on Website (minutes)       0
# Length of Membership (years)    0
# Yearly Amount Spent ($)         0
# dtype: int64

# %%
# Encode Sex
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#    Gender  Age  Annual Income ($)  Time on App (minutes)  \
# 0       1   49             106213                  12.05
# 1       0   56              35895                   7.95
# 2       1   66              49738                  22.42
# 3       1   69              60746                  20.72
# 4       1   49              79377                  26.94
#
#    Time on Website (minutes)  Length of Membership (years)  \
# 0                      20.33                           6.8
# 1                      28.37                           7.2
# 2                      49.20                           5.9
# 3                      29.70                           3.3
# 4                      23.15                           4.1
#
#    Yearly Amount Spent ($)
# 0                  1096.84
# 1                   834.24
# 2                  1270.91
# 3                   606.60
# 4                   575.14

# %%
# Normalization of data
Scaler=StandardScaler()
df_Scaled=Scaler.fit_transform(df)

# %%
# 3. Analysis the data
# comparing gender with other numberical data
df.corr()
sns.heatmap(data=df.corr(),annot=True ,cmap='Blues')
# Out:
# <Axes: >

# %%
sns.relplot(x='Annual Income ($)',y='Yearly Amount Spent ($)' , hue= 'Gender',data=df)

# %%
sns.barplot(x='Gender',y='Yearly Amount Spent ($)',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Yearly Amount Spent ($)'>

# %%
sns.barplot(x='Gender',y='Length of Membership (years)',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Length of Membership (years)'>

# %%
sns.barplot(x='Gender',y='Time on Website (minutes)',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Time on Website (minutes)'>

# %%
sns.barplot(x='Gender',y='Time on App (minutes)',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Time on App (minutes)'>

# %%
plt.hist(x='Length of Membership (years)', data=df, bins=5)
# Out:
# (array([45., 37., 48., 33., 37.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.displot(df['Yearly Amount Spent ($)'], bins=5)
